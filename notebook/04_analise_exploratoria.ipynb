# %% [markdown]
# # 04 - Avaliação do Modelo

# %% [markdown]
# ## Carregar modelo

# %%
import torch,json
from model import ClassificadorDiario
with open('../data/processed/vocab.json',encoding='utf8') as f:vocab=json.load(f)
model=ClassificadorDiario(len(vocab),100,3)
model.load_state_dict(torch.load('../models/model.pt',map_location='cpu'))
model.eval()

# %% [markdown]
# ## Dataset

# %%
import pandas as pd
df=pd.read_csv('../data/processed/dataset_final.csv')
df.head()

# %% [markdown]
# ## Exemplo de inferência

# %%
# adapte a função encode do projeto para testar novas entradas
